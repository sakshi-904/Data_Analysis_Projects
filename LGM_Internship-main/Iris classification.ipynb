# %% [markdown]
# ***Lets Grow More***
#
# **2)Intermediate level task:
#  Sub task 02)**

# %% [markdown]
# **Title:** Iris Flowers Classification ML Project

# %% [markdown]
# # Introduction:
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.

# %% [markdown]
# **Importing pandas and Seaborn module**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')  #this will ignore the warnings.it wont display warnings in notebook

# %% [markdown]
# **Importing Iris data set**

# %%
iris_df=pd.read_csv('Iris.csv')

# %% [markdown]
# **Displaying data**

# %%
iris_df.head()
# Out:
#    Column1  Column2  Column3  Column4      Column5
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
iris_df.rename(columns={"Column1":"Sepel_Length","Column2":"Sepel_Width","Column3":"Petal_Length","Column4":"Petal_Width","Column5":"Species"},inplace=True)

# %% [markdown]
# **Checking if there are any missing values**

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepel_Length  150 non-null    float64
#  1   Sepel_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.isnull().sum()
# Out:
# Sepel_Length    1
# Sepel_Width     1
# Petal_Length    1
# Petal_Width     1
# Species         1
# dtype: int64

# %%
iris_df.dropna(inplace=True)

# %%
iris_df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# This data set has three varities of Iris plant.

# %% [markdown]
# **1. Describing the data**

# %%
iris_df.describe().plot(kind = "area", figsize = (20,8), table = True,colormap="rainbow")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Iris Dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of Iris Dataset')

# %% [markdown]
# Above plot gives us a General Idea about the dataset.

# %% [markdown]
# **2.Bar Plot :**
# Here the frequency of the observation is plotted.In this case we are plotting the frequency of the three species in the Iris Dataset

# %%
#f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Species',data=iris_df)
#ax.set_title('Iris Species Count')
plt.show()

# %% [markdown]
# **3. Pie Chart :**

# %%
#f,ax=plt.subplots(1,2,figsize=(18,8))
iris_df['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# We can see that there are 50 samples each of all the Iris Species in the data set.

# %%
sns.pairplot(data=iris_df,kind='scatter')
pass

# %%
sns.pairplot(iris_df,hue='Species');

# %% [markdown]
# # Model Training

# %%
# train - 70
# test - 30
X = iris_df.drop(columns=['Species'])
Y = iris_df['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
# logistic regression 

model = LogisticRegression()

# %%
# model training
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  97.77777777777777

# %%
# knn - k-nearest neighbours

model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  97.77777777777777

# %%
# decision tree
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  95.55555555555556

# %% [markdown]
# # Conclusion
#
# Accuracy:
# <br> - LogisticRegression: 100
# <br> - KNeighborsClassifier: 95.55
# <br> - DecisionTreeClassifier: 100
